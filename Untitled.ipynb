# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn import preprocessing
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
#df['class'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# #### Let's do PCA!

# %% [markdown]
# 1. Center and scale

# %%
## first way to scale
scaled_data1 = preprocessing.scale(df,axis = 0)

## second way to scale
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
pca = PCA()

# %%
pca.fit(scaled_data)
# Out:
# PCA()

# %%
pca_data = pca.transform(scaled_data)

# %%
per_var = np.round(pca.explained_variance_ratio_ * 100,2)

# %%
labels = ['PC' + str(i+1) + ' ' + df.columns[i] for i in range(len(per_var))]

# %%
fig, ax = plt.subplots(figsize=(8, 6)) # Adjust the size
ax.bar(labels, per_var)

# Add x-label and y-label
ax.set_xlabel('PC')
ax.set_ylabel('% of variance explained ')
ax.set_xticklabels(labels, rotation=45)
plt.show()
# Out:
# C:\Users\vak82\AppData\Local\Temp\ipykernel_9620\3033499543.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, rotation=45)

# %% [markdown]
# #### Great - this tells us that the principal components are PC1 and PC2. We can now proceed to making a scatter plot with these principal components.

# %%
pca_df = pd.DataFrame(data = pca_data, columns = labels)

# %%
plt.text()

# %%
sns.scatterplot(x=pca_df['PC1 sepal length (cm)'], y=pca_df['PC2 sepal width (cm)'])
for row,val in pca_df.iterrows():
    plt.text(val[0], val[1]+.2, s= iris.target[row])

# %% [markdown]
# This is our final result. We now see the groups are perfectly distinct, and discernable.
